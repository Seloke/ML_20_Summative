# %% [markdown]
# # Machine learning summative assessment - Airline Avionics

# %% [markdown]
# ## Task 1 Import and clean data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('ml_summative_raw.csv')
data.head()
# Out:
#    Unnamed: 0        date    serial_number                 model  \
# 0           1  2016-01-01         Z304AESX           ST4000DM000
# 1           2  2016-01-01   PL2331LAGPRW3J  HGST HMS5C4040ALE640
# 2           3  2016-01-01         Z300ZST1           ST4000DM000
# 3           4  2016-01-01         Z300GQ9R           ST4000DM000
# 4           5  2016-01-01  WD-WMC4M2889605          WDC WD20EFRX
#
#    capacity_bytes  failure  Throughput Performance  Spin-Up Time  \
# 0   4000787030016        0                     NaN          96.0
# 1   4000787030016        0                   134.0         138.0
# 2   4000787030016        0                     NaN          91.0
# 3   4000787030016        0                     NaN          91.0
# 4   2000398934016        0                     NaN         100.0
#
#    Start/Stop Count  Reallocated Sectors Count       ...         \
# 0             100.0                      100.0       ...
# 1             100.0                      100.0       ...
# 2             100.0                      100.0       ...
# 3             100.0                      100.0       ...
# 4             100.0                      200.0       ...
#
#    Load/Unload Cycle Count  Load In-time  \
# 0                      NaN           NaN
# 1                      NaN           NaN
# 2                      NaN           NaN
# 3                      NaN           NaN
# 4                      NaN           NaN
#
#    Head Flying Hours or 'Transfer Error Rate'(Fujitsu)  Total LBAs Written  \
# 0                                              100.0                 100.0
# 1                                                NaN                   NaN
# 2                                              100.0                 100.0
# 3                                              100.0                 100.0
# 4                                                NaN                   NaN
#
#    Total LBAs Read  Read Error Retry Rate  Minimum Spares Remaining  \
# 0            100.0                    NaN                       NaN
# 1              NaN                    NaN                       NaN
# 2            100.0                    NaN                       NaN
# 3            100.0                    NaN                       NaN
# 4              NaN                    NaN                       NaN
#
#    Newly Added Bad Flash Block  Free Fall Protection  Read Error Rate
# 0                          NaN                   NaN            114.0
# 1                          NaN                   NaN            100.0
# 2                          NaN                   NaN            120.0
# 3                          NaN                   NaN            117.0
# 4                          NaN                   NaN            200.0
#
# [5 rows x 50 columns]

# %%
##Cleaning the data!!

data.isnull().sum()
# Out:
# Unnamed: 0                                                                                     0
# date                                                                                           0
# serial_number                                                                                  0
# model                                                                                          0
# capacity_bytes                                                                                 0
# failure                                                                                        0
# Throughput Performance                                                                     65504
# Spin-Up Time                                                                                   2
# Start/Stop Count                                                                               2
# Reallocated Sectors Count                                                                      2
# Seek Error Rate                                                                                2
# Seek Time Performance                                                                      65504
# Power-On Hours                                                                                 2
# Spin Retry Count                                                                               2
# Recalibration Retriesor Calibration Retry Count                                            68171
# Power Cycle Count                                                                              2
# Soft Read Error Rate                                                                       75130
# smart_15                                                                                   75130
# Current Helium Level                                                                       75130
# SATA Downshift Error Count or Runtime Bad Block                                            21737
# End-to-End error / IOEDC                                                                   15959
# Reported Uncorrectable Errors                                                              15959
# Command Timeout                                                                            15959
# High Fly Writes                                                                            16019
# Temperature Difference or Airflow Temperature                                              15899
# G-sense Error Rate                                                                         15621
# Power-off Retract Count, Emergency Retract Cycle Count(Fujitsu)or Unsafe Shutdown Count     1086
# Load Cycle Count or Load/Unload Cycle Count (Fujitsu)                                       1654
# Temperature or Temperature Celsius                                                            62
# Hardware ECC Recovered                                                                     65846
# Reallocation Event Count                                                                   59113
# Current Pending Sector Count                                                                   2
# (Offline) Uncorrectable Sector Count                                                           2
# UltraDMA CRC Error Count                                                                       2
# Write Error Rate(Fujitsu)                                                                  68171
# Soft Read Error Rateor                                                                     75130
# Disk Shift                                                                                 75070
# Loaded Hours                                                                               75070
# Load/Unload Retry Count                                                                    74502
# Load Friction                                                                              75070
# Load/Unload Cycle Count                                                                    74562
# Load In-time                                                                               75070
# Head Flying Hours or 'Transfer Error Rate'(Fujitsu)                                        16009
# Total LBAs Written                                                                         16129
# Total LBAs Read                                                                            16129
# Read Error Retry Rate                                                                      71562
# Minimum Spares Remaining                                                                   71562
# Newly Added Bad Flash Block                                                                71562
# Free Fall Protection                                                                       71334
# Read Error Rate                                                                              598
# dtype: int64

# %%
data = data.fillna(data.mean(axis=0))
data.isnull().sum()
# Out:
# Unnamed: 0                                                                                     0
# date                                                                                           0
# serial_number                                                                                  0
# model                                                                                          0
# capacity_bytes                                                                                 0
# failure                                                                                        0
# Throughput Performance                                                                         0
# Spin-Up Time                                                                                   0
# Start/Stop Count                                                                               0
# Reallocated Sectors Count                                                                      0
# Seek Error Rate                                                                                0
# Seek Time Performance                                                                          0
# Power-On Hours                                                                                 0
# Spin Retry Count                                                                               0
# Recalibration Retriesor Calibration Retry Count                                                0
# Power Cycle Count                                                                              0
# Soft Read Error Rate                                                                       75130
# smart_15                                                                                   75130
# Current Helium Level                                                                       75130
# SATA Downshift Error Count or Runtime Bad Block                                                0
# End-to-End error / IOEDC                                                                       0
# Reported Uncorrectable Errors                                                                  0
# Command Timeout                                                                                0
# High Fly Writes                                                                                0
# Temperature Difference or Airflow Temperature                                                  0
# G-sense Error Rate                                                                             0
# Power-off Retract Count, Emergency Retract Cycle Count(Fujitsu)or Unsafe Shutdown Count        0
# Load Cycle Count or Load/Unload Cycle Count (Fujitsu)                                          0
# Temperature or Temperature Celsius                                                             0
# Hardware ECC Recovered                                                                         0
# Reallocation Event Count                                                                       0
# Current Pending Sector Count                                                                   0
# (Offline) Uncorrectable Sector Count                                                           0
# UltraDMA CRC Error Count                                                                       0
# Write Error Rate(Fujitsu)                                                                      0
# Soft Read Error Rateor                                                                     75130
# Disk Shift                                                                                     0
# Loaded Hours                                                                                   0
# Load/Unload Retry Count                                                                        0
# Load Friction                                                                                  0
# Load/Unload Cycle Count                                                                        0
# Load In-time                                                                                   0
# Head Flying Hours or 'Transfer Error Rate'(Fujitsu)                                            0
# Total LBAs Written                                                                             0
# Total LBAs Read                                                                                0
# Read Error Retry Rate                                                                          0
# Minimum Spares Remaining                                                                       0
# Newly Added Bad Flash Block                                                                    0
# Free Fall Protection                                                                           0
# Read Error Rate                                                                                0
# dtype: int64

# %%
data = data.dropna(axis='columns')

#Dropping all the non numeric columns

data.drop('Unnamed: 0', axis=1, inplace=True)
data.drop('date', axis=1, inplace=True)
data.drop('serial_number', axis=1, inplace=True)
data.drop('model', axis=1, inplace=True)
data.isnull().sum()

# %%
#Discriptive Statistics

data.describe()
# Out:
#        capacity_bytes       failure  Throughput Performance  Spin-Up Time  \
# count    7.513000e+04  75130.000000            75130.000000  75130.000000
# mean     3.666340e+12      0.018594              130.084563    102.174835
# std      1.423955e+12      0.135089               12.265414     21.576988
# min     -1.000000e+00      0.000000              100.000000     85.000000
# 25%      4.000787e+12      0.000000              130.084563     92.000000
# 50%      4.000787e+12      0.000000              130.084563     95.000000
# 75%      4.000787e+12      0.000000              130.084563     98.000000
# max      8.001563e+12      1.000000              252.000000    253.000000
#
#        Start/Stop Count  Reallocated Sectors Count  Seek Error Rate  \
# count      75130.000000               75130.000000     75130.000000
# mean          99.985611                 109.128061        93.192498
# std            0.481049                  31.055106        26.428754
# min           83.000000                   1.000000        26.000000
# 25%          100.000000                 100.000000        84.000000
# 50%          100.000000                 100.000000        87.000000
# 75%          100.000000                 100.000000        90.000000
# max          100.000000                 252.000000       252.000000
#
#        Seek Time Performance  Power-On Hours  Spin Retry Count  \
# count           75130.000000    75130.000000      75130.000000
# mean              120.649283       83.165451        101.145192
# std                12.486162       13.571579         13.167474
# min                11.000000        1.000000         95.000000
# 25%               120.649283       74.000000        100.000000
# 50%               120.649283       85.000000        100.000000
# 75%               120.649283       94.000000        100.000000
# max               252.000000      100.000000        252.000000
#
#             ...         Load/Unload Cycle Count  Load In-time  \
# count       ...                    75130.000000       75130.0
# mean        ...                       80.714789         100.0
# std         ...                        0.828246           0.0
# min         ...                       56.000000         100.0
# 25%         ...                       80.714789         100.0
# 50%         ...                       80.714789         100.0
# 75%         ...                       80.714789         100.0
# max         ...                       98.000000         100.0
#
#        Head Flying Hours or 'Transfer Error Rate'(Fujitsu)  \
# count                                       75130.000000
# mean                                           99.950238
# std                                             0.993018
# min                                            71.000000
# 25%                                           100.000000
# 50%                                           100.000000
# 75%                                           100.000000
# max                                           100.000000
#
#        Total LBAs Written  Total LBAs Read  Read Error Retry Rate  \
# count        75130.000000     75130.000000           75130.000000
# mean           100.099998       100.099998               1.027747
# std              2.800947         2.800947               0.361136
# min            100.000000       100.000000               1.000000
# 25%            100.000000       100.000000               1.027747
# 50%            100.000000       100.000000               1.027747
# 75%            100.000000       100.000000               1.027747
# max            200.000000       200.000000             100.000000
#
#        Minimum Spares Remaining  Newly Added Bad Flash Block  \
# count              75130.000000                 75130.000000
# mean                   1.554933                     9.074271
# std                    1.610741                     5.904779
# min                    1.000000                     1.000000
# 25%                    1.554933                     9.074271
# 50%                    1.554933                     9.074271
# 75%                    1.554933                     9.074271
# max                  100.000000                   100.000000
#
#        Free Fall Protection  Read Error Rate
# count          75130.000000     75130.000000
# mean             101.554268       118.856254
# std                2.780486        28.290474
# min              100.000000        15.275819
# 25%              101.554268       111.000000
# 50%              101.554268       116.000000
# 75%              101.554268       118.000000
# max              200.000000       200.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ## Task 2 Inspect and visualize the data

# %%
#Histograms
pd.DataFrame.hist(data.sample(frac=0.1), figsize = [30,30]);

# %%
#Correlations within data sets

corr = data.corr()
plt.figure(figsize=(30,30))
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %% [markdown]
# ## Task 3 Feature engineering

# %%
data.groupby('failure').count()
# Out:
#          capacity_bytes  Throughput Performance  Spin-Up Time  \
# failure
# 0                 73733                   73733         73733
# 1                  1397                    1397          1397
#
#          Start/Stop Count  Reallocated Sectors Count  Seek Error Rate  \
# failure
# 0                   73733                      73733            73733
# 1                    1397                       1397             1397
#
#          Seek Time Performance  Power-On Hours  Spin Retry Count  \
# failure
# 0                        73733           73733             73733
# 1                         1397            1397              1397
#
#          Recalibration Retriesor Calibration Retry Count       ...         \
# failure                                                        ...
# 0                                                  73733       ...
# 1                                                   1397       ...
#
#          Load/Unload Cycle Count  Load In-time  \
# failure
# 0                          73733         73733
# 1                           1397          1397
#
#          Head Flying Hours or 'Transfer Error Rate'(Fujitsu)  \
# failure
# 0                                                    73733
# 1                                                     1397
#
#          Total LBAs Written  Total LBAs Read  Read Error Retry Rate  \
# failure
# 0                     73733            73733                  73733
# 1                      1397             1397                   1397
#
#          Minimum Spares Remaining  Newly Added Bad Flash Block  \
# failure
# 0                           73733                        73733
# 1                            1397                         1397
#
#          Free Fall Protection  Read Error Rate
# failure
# 0                       73733            73733
# 1                        1397             1397
#
# [2 rows x 41 columns]

# %%
sns.countplot(x='failure',data=data, palette='hls')

# %% [markdown]
# Logistic Regission is chosen as the results can be are labeled as binary.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
X = data.drop(['failure'], axis = 1).values # X are the input (or independent) variables
y = data['failure'].values # Y is output (or dependent) variable
dataSmall = data.drop(['failure'], axis = 1)
dataSmall.isnull().sum()
# Out:
# capacity_bytes                                                                             0
# Throughput Performance                                                                     0
# Spin-Up Time                                                                               0
# Start/Stop Count                                                                           0
# Reallocated Sectors Count                                                                  0
# Seek Error Rate                                                                            0
# Seek Time Performance                                                                      0
# Power-On Hours                                                                             0
# Spin Retry Count                                                                           0
# Recalibration Retriesor Calibration Retry Count                                            0
# Power Cycle Count                                                                          0
# SATA Downshift Error Count or Runtime Bad Block                                            0
# End-to-End error / IOEDC                                                                   0
# Reported Uncorrectable Errors                                                              0
# Command Timeout                                                                            0
# High Fly Writes                                                                            0
# Temperature Difference or Airflow Temperature                                              0
# G-sense Error Rate                                                                         0
# Power-off Retract Count, Emergency Retract Cycle Count(Fujitsu)or Unsafe Shutdown Count    0
# Load Cycle Count or Load/Unload Cycle Count (Fujitsu)                                      0
# Temperature or Temperature Celsius                                                         0
# Hardware ECC Recovered                                                                     0
# Reallocation Event Count                                                                   0
# Current Pending Sector Count                                                               0
# (Offline) Uncorrectable Sector Count                                                       0
# UltraDMA CRC Error Count                                                                   0
# Write Error Rate(Fujitsu)                                                                  0
# Disk Shift                                                                                 0
# Loaded Hours                                                                               0
# Load/Unload Retry Count                                                                    0
# Load Friction                                                                              0
# Load/Unload Cycle Count                                                                    0
# Load In-time                                                                               0
# Head Flying Hours or 'Transfer Error Rate'(Fujitsu)                                        0
# Total LBAs Written                                                                         0
# Total LBAs Read                                                                            0
# Read Error Retry Rate                                                                      0
# Minimum Spares Remaining                                                                   0
# Newly Added Bad Flash Block                                                                0
# Free Fall Protection                                                                       0
# Read Error Rate                                                                            0
# dtype: int64

# %% [markdown]
# Since the Data set is very large - I use recursive feature elimination algorithm to determine those features that are important for predicting the outcome of interest.

# %%
from sklearn.feature_selection import RFE # import the package

# %%
logreg = LogisticRegression() # create the model

# %%
##First recursive feature elimination
selector = RFE(logreg) # defaults to half the features
selector = selector.fit(X, y)
print(selector.support_)
print(selector.ranking_)
# Out:
# [ True  True  True False  True  True  True False  True  True False False
#  False False False False False  True  True False False False  True  True
#   True  True  True False False  True False False False False  True  True
#  False False False  True  True]
# [ 1  1  1  9  1  1  1 18  1  1  4 11  8  2  3 12 16  1  1 13 17 19  1  1
#   1  1  1  7 15  1  5 14  6 10  1  1 22 21 20  1  1]

# %%
#Second recursive feature elimination

cols = [3,7,10,11,12,13,14,15,16,19,20,21,27,28,30,31,32,33]
dataSmall = dataSmall.drop(dataSmall.columns[cols], axis=1)
X = dataSmall.values
selector = RFE(logreg) # defaults to half the features
selector = selector.fit(X, y)
print(selector.support_)
print(selector.ranking_)
# Out:
# [ True  True False  True  True  True False False False  True  True  True
#  False  True  True False False False False False False False  True]
# [ 1  1  3  1  1  1  5  8  6  1  1  1  2  1  1  4  9 10 13 12 11  7  1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
print('Training data', len(X_train), len(y_train))
print('Test data', len(X_test), len(y_test))
# Out:
# Training data 52591 52591
# Test data 22539 22539

# %% [markdown]
# ## Task 4 Model fitting

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ## Task 5 Model evaluation

# %%
y_pred = logreg.predict(X_test)
print('Accuracy score: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy score: 0.98

# %% [markdown]
# ## Task 6 Produce recommendations

# %% [markdown]
# From the recursive feature elimination algorithm the following features are stongly correlated to whether there
# will be a failure or not:
# 1. capacity_bytes,
# 2. Spin-Up Time
# 3. Start/Stop Count
# 4. Reallocated Sectors Count
# 5. Temperature Difference or Airflow Temperature
# 6. Temperature or Temperature Celsius
# 7. Hardware ECC Recovered
# 8. Current Pending Sector Count
# 9. (Offline) Uncorrectable Sector Count
#
# Design improvements on the items aboive is recomended.
